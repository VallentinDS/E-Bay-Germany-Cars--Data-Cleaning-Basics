# %% [markdown]
# # Guided Project: Exploring Ebay Car Sales Data

# %% [markdown]
# ### In this guided project, I will work work with a dataset of used cars from eBay Kleinanzeigen, a classified section of the German eBay website
#
# ##### The original dataset isn't available on Kaggle anymore, but you can find it [here](https://data.world/data-society/used-cars-data)
#
# ### The aim of this project is to clean the data and analyze the included used car listings

# %% [markdown]
# There were made a few modifications from the original dataset:
#
# - There were sampled 50,000 data points from the full dataset, to ensure the code runs quickly in our hosted environment
# - The dataset was dirtied a bit to more closely resemble what we would expect from a scraped dataset (the version uploaded to Kaggle was cleaned to be easier to work with)
#
# The aim of this project is to clean the data and analyze the included used car listings. You'll also become familiar with some of the unique benefits jupyter notebook provides for pandas.

# %% [markdown]
# **The data dictionary provided with data is as follows:**
#
# `dateCrawled` - When this ad was first crawled. All field-values are taken from this date.
#
# `name` - Name of the car.
#
# `seller` - Whether the seller is private or a dealer.
#
# `offerType` - The type of listing
#
# `price` - The price on the ad to sell the car.
#
# `abtest` - Whether the listing is included in an A/B test.
#
# `vehicleType` - The vehicle Type.
#
# `yearOfRegistration` - The year in which the car was first registered.
#
# `gearbox` - The transmission type.
#
# `powerPS` - The power of the car in PS.
#
# `model` - The car model name.
#
# `kilometer` - How many kilometers the car has driven.
#
# `monthOfRegistration` - The month in which the car was first registered.
#
# `fuelType` - What type of fuel the car uses.
#
# `brand` - The brand of the car.
#
# `notRepairedDamage` - If the car has a damage which is not yet repaired.
#
# `dateCreated` - The date on which the eBay listing was created.
#
# `nrOfPictures` - The number of pictures in the ad.
#
# `postalCode` - The postal code for the location of the vehicle.
#
# `lastSeenOnline` - When the crawler saw this ad last online.

# %%
import numpy as np
import pandas as pd

# %%
autos= pd.read_csv("autos.csv", encoding= "Latin-1")

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %% [markdown]
# #### What do we know so far
#
# From the information about the `autos` dataframe, we can see that:
#     - The dataset contains 20 columns, most of which are strings
#     - Column names use camelcase instead of Python's preferred snakecase. I cannot replace the spaces with underscores.
#     - `price` column has comma and $ sign.
#         - The latter definitely needs to be removed and the column label renamed to indicate that the price is in dollars
#     - `vehicleType, gearbox, model, fuelType` and  `notRepairedDamage` columns have missing values `NaN`. The null values are not more than ~20%
#     - `odometer` column contains numeric data and string `km`

# %% [markdown]
# ### Cleaning column names
#
# I will convert the column names from camelcase to snakecase. I will also do some rewording on the column names based on the data dictionary to be more descriptive.

# %%
print(autos.columns)
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.columns= [
"date_crawled",
"name",
"seller",
"offer_type",
"price",
"ab_test",
"vechile_type",
"registration_year",
"gearbox",
"power_ps",
"model",
"odometer",
"registration_month",
'fuel_type',
"brand",
"unrepaired_damage",
"ad_created",
"nr_pictures",
"post_code",
"last_seen"]

# %%
autos
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %% [markdown]
# In the cell above, I have converted the column names from camelcase to snakecase, to respect the Python's preferred writing syntax.
# Moreover, I have brought small changes to the column names to be more descriptive of the data.

# %% [markdown]
# ### Initial exploring and cleaning
#
# Now it is time to do some basic data exploration to determine what other cleaning tasks need to be done. Initially, I will look for:
#
# - Text columns where all or almost all values are the same. These can often be dropped as they don't have useful information for analysis.
# - A second important step is to look for examples of numeric data stored as text which can be cleaned and converted.

# %%
autos.describe(include= "all")
# Out:
#                date_crawled         name  seller offer_type  price ab_test  \
# count                 50000        50000   50000      50000  50000   50000
# unique                48213        38754       2          2   2357       2
# top     2016-03-05 16:57:05  Ford_Fiesta  privat    Angebot     $0    test
# freq                      3           78   49999      49999   1421   25756
# mean                    NaN          NaN     NaN        NaN    NaN     NaN
# std                     NaN          NaN     NaN        NaN    NaN     NaN
# min                     NaN          NaN     NaN        NaN    NaN     NaN
# 25%                     NaN          NaN     NaN        NaN    NaN     NaN
# 50%                     NaN          NaN     NaN        NaN    NaN     NaN
# 75%                     NaN          NaN     NaN        NaN    NaN     NaN
# max                     NaN          NaN     NaN        NaN    NaN     NaN
#
# ...

# %%
print(autos["nr_pictures"].value_counts())
print('\n')
print(autos["ab_test"].value_counts())
print('\n')
print(autos["seller"].value_counts())
print('\n')
print(autos["offer_type"].value_counts())
# Out:
# 0    50000
# Name: nr_pictures, dtype: int64
#
#
# test       25756
# control    24244
# Name: ab_test, dtype: int64
#
#
# privat        49999
# gewerblich        1
# Name: seller, dtype: int64
#
#
# Angebot    49999
# Gesuch         1
# Name: offer_type, dtype: int64

# %% [markdown]
# Making use of the `autos.describe(include= 'all')` method, I inpsected the columns and concluded the following:
#
# - `nr_pictures` column can be dropped for the analysis because the only value it has is `0.0`, deeming it irrelevant for our analysis
#
# - `ab_test` column can be dropped as well
#
# - `registratrion_year` would need to be inspected more because be min and max values are 1000 and 9999 which is fairly impossible for a car's registration years
#
# - `power_ps` min value is 0 which is very unlikely for a car to have zero horsepower
#
# - `registration_month` min value is also 0
# - `seller` and `offer_type` columns have the same values
# - `date_crawled` could be transformed into a datetime object
#
# For the columns `price` and `odometer`, which are stored as text, will need to convert them to numerical data. I will:
#
# - remove any non-numeric characters
# - convert the column to a numeric type
# - rename the `odometer` column to `odometer_km`

# %%
autos["price"].unique()
# Out:
# array(['$5,000', '$8,500', '$8,990', ..., '$385', '$22,200', '$16,995'],
#       dtype=object)

# %%
autos["price"]= autos["price"].str.replace('$', "").str.replace(',', "").astype(int)
autos["price"]
# Out:
# 0         5000
# 1         8500
# 2         8990
# 3         4350
# 4         1350
# 5         7900
# 6          300
# 7         1990
# 8          250
# 9          590
# 10         999
# 11         350
# 12        5299
# 13        1350
# 14        3999
# 15       18900
# 16         350
# 17        5500
# 18         300
# 19        4150
# 20        3500
# 21       41500
# 22       25450
# 23        7999
# 24       48500
# 25          90
# 26         777
# 27           0
# 28        5250
# 29        4999
#          ...
# 49970    15800
# 49971      950
# 49972     3300
# 49973     6000
# 49974        0
# 49975     9700
# 49976     5900
# 49977     5500
# 49978      900
# 49979    11000
# 49980      400
# 49981     2000
# 49982     1950
# 49983      600
# 49984        0
# 49985     1000
# 49986    15900
# 49987    21990
# 49988     9550
# 49989      150
# 49990    17500
# 49991      500
# 49992     4800
# 49993     1650
# 49994     5000
# 49995    24900
# 49996     1980
# ...

# %%
autos["odometer"].unique()
# Out:
# array(['150,000km', '70,000km', '50,000km', '80,000km', '10,000km',
#        '30,000km', '125,000km', '90,000km', '20,000km', '60,000km',
#        '5,000km', '100,000km', '40,000km'], dtype=object)

# %%
autos["odometer"]= autos["odometer"].str.replace('km', "").str.replace(',', "").astype(int)
autos["odometer"]

autos.rename({"odometer": "odometer_km"}, axis= 1, inplace= True)

# %%
autos= autos.drop(["nr_pictures", "ab_test"], axis= 1)

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 18 columns):
# date_crawled          50000 non-null object
# name                  50000 non-null object
# seller                50000 non-null object
# offer_type            50000 non-null object
# price                 50000 non-null int64
# vechile_type          44905 non-null object
# registration_year     50000 non-null int64
# gearbox               47320 non-null object
# power_ps              50000 non-null int64
# model                 47242 non-null object
# odometer_km           50000 non-null int64
# registration_month    50000 non-null int64
# fuel_type             45518 non-null object
# brand                 50000 non-null object
# unrepaired_damage     40171 non-null object
# ad_created            50000 non-null object
# post_code             50000 non-null int64
# last_seen             50000 non-null object
# dtypes: int64(6), object(12)
# memory usage: 6.9+ MB

# %%
autos.describe(include= "all")
# Out:
#                date_crawled         name  seller offer_type         price  \
# count                 50000        50000   50000      50000  5.000000e+04
# unique                48213        38754       2          2           NaN
# top     2016-03-05 16:57:05  Ford_Fiesta  privat    Angebot           NaN
# freq                      3           78   49999      49999           NaN
# mean                    NaN          NaN     NaN        NaN  9.840044e+03
# std                     NaN          NaN     NaN        NaN  4.811044e+05
# min                     NaN          NaN     NaN        NaN  0.000000e+00
# 25%                     NaN          NaN     NaN        NaN  1.100000e+03
# 50%                     NaN          NaN     NaN        NaN  2.950000e+03
# 75%                     NaN          NaN     NaN        NaN  7.200000e+03
# max                     NaN          NaN     NaN        NaN  1.000000e+08
#
#        vechile_type  registration_year  gearbox      power_ps  model  \
# ...

# %% [markdown]
# ### Exploring the Odometer and Price Columns
#
# I have converted `price` and `odometer` to numeric types and renamed `odometer` to `odometer_km`
#
# For the begining , these columns need further attention as there are some values that seem unrealistic while using the `DataFrame.describe()` method and they might be required to be removed in order to not jeopardize the analysis.

# %%
print(autos["price"].unique().shape)
# Out:
# (2357,)

# %%
print(autos["price"].describe())
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %%
print(autos["price"].value_counts().sort_index(ascending= True))
# Out:
# 0           1421
# 1            156
# 2              3
# 3              1
# 5              2
# 8              1
# 9              1
# 10             7
# 11             2
# 12             3
# 13             2
# 14             1
# 15             2
# 17             3
# 18             1
# 20             4
# 25             5
# 29             1
# 30             7
# 35             1
# 40             6
# 45             4
# 47             1
# 49             4
# 50            49
# 55             2
# 59             1
# 60             9
# 65             5
# 66             1
#             ...
# 151990         1
# 155000         1
# 163500         1
# 163991         1
# 169000         1
# 169999         1
# 175000         1
# 180000         1
# 190000         1
# 194000         1
# 197000         1
# 198000         1
# 220000         1
# 250000         1
# 259000         1
# 265000         1
# 295000         1
# 299000         1
# 345000         1
# 350000         1
# 999990         1
# ...

# %% [markdown]
# By inspecting the series `autos["price"]`, I can see that there are 1421 values corresponding to 0 and other values that are up to the price of 500.
#
# Some of the prices are unrealistic fo some used cars such as `99999999` or `12345678`, `10000000` even if they are high-end brands. For this, I made some simple boolean indexing to show that the prices are unrealistic

# %%
autos.loc[autos["price"]== 99999999, "brand"]
# Out:
# 39705    mercedes_benz
# Name: brand, dtype: object

# %%
autos.loc[autos["price"]== 500, "brand"]
# Out:
# 148          volkswagen
# 283      sonstige_autos
# 320             peugeot
# 371              nissan
# 433                 bmw
# 541                opel
# 542       mercedes_benz
# 652                ford
# 675               honda
# 694                ford
# 756          volkswagen
# 778          volkswagen
# 819                 kia
# 842                 bmw
# 864          volkswagen
# 897                opel
# 898          volkswagen
# 924                opel
# 926                ford
# 956               honda
# 979                audi
# 1205         volkswagen
# 1223            renault
# 1416         volkswagen
# 1438            renault
# 1509             toyota
# 1539               ford
# 1627               fiat
# 1641           chrysler
# 1678            citroen
#               ...
# 48284            lancia
# 48305              opel
# 48312             smart
# 48405        volkswagen
# 48413              fiat
# 48421               bmw
# 48437        volkswagen
# ...

# %% [markdown]
# I will remove the 0 values and also the values above 999990, thus I will be left with a more realistic set of data regarding the pricing for the cars.

# %%
autos= autos[autos["price"].between(500, 350000)]

# %%
print(autos["price"].describe())
# Out:
# count     45097.000000
# mean       6320.659600
# std        9261.841444
# min         500.000000
# 25%        1500.000000
# 50%        3500.000000
# 75%        7900.000000
# max      350000.000000
# Name: price, dtype: float64

# %%
print(autos["price"].unique().shape)
# Out:
# (2208,)

# %% [markdown]
# I have been left only with 2208 or rows regarding the price, from the total of 2357. This can mean that there is plenty of data in this column to support our analysis when we will get there.

# %%
print(autos["odometer_km"].unique().shape)
# Out:
# (13,)

# %%
print(autos["odometer_km"].describe())
# Out:
# count     45097.000000
# mean     125293.035013
# std       39622.744927
# min        5000.000000
# 25%      100000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
print(autos["odometer_km"].value_counts().sort_index(ascending= True))
# Out:
# 5000        616
# 10000       237
# 20000       727
# 30000       765
# 40000       808
# 50000       996
# 60000      1131
# 70000      1189
# 80000      1385
# 90000      1676
# 100000     2031
# 125000     4838
# 150000    28698
# Name: odometer_km, dtype: int64

# %% [markdown]
# So far, the `odometer_km` seem to have realistic data and I will got go any further to clean it.

# %% [markdown]
# ### Exploring the date columns
#
#
# There are 5 columns that represent the date values taking from the crawler of from the website itself:
#
# - `date_crawled`: added by the crawler
# - `last_seen`: added by the crawler
# - `ad_created`: from the website
# - `registration_month`: from the website
# - `registration_year`: from the website
#
# Right now, the `date_crawled`, `last_seen`, and `ad_created` columns are all identified as string values by pandas. Because these three columns are represented as strings, we need to convert the data into a numerical representation so we can understand it quantitatively. The other two columns are represented as numeric values, so we can use methods like `Series.describe()` to understand the distribution without any extra data processing.

# %%
# Thought that this can be used to transform the date columns in datetime objects but it is not necessary
# `autos[["date_crawled", "ad_created", "last_seen", "registration_year", "registration_month"]]= autos[["date_crawled", "ad_created", "last_seen", "registration_year", "registration_month"]].astype("datetime64[ns]")`

# %% [markdown]
# Let's first understand how the values in the three string columns are formatted. These columns all represent full timestamp values, like so:

# %%
autos[['date_crawled','ad_created','last_seen']][0:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %% [markdown]
# It is important to notice that the first 10 characters in every column represent the year, month and day. I would like to sort the dates in order to get a date range for the sales of the cars.
#
# I will extract the date values and use `Series.value_counts()` to generate a distribution which I will then sort by the index.
#
# First, I will select the first 10 characters in each column

# %%
autos["date_crawled"].str[:10].shape
# Out:
# (45097,)

# %%
autos["date_crawled"].str[:10].value_counts(normalize= True, dropna= False).sort_index(ascending= True)
# Out:
# 2016-03-05    0.025567
# 2016-03-06    0.014125
# 2016-03-07    0.036189
# 2016-03-08    0.033173
# 2016-03-09    0.032907
# 2016-03-10    0.032707
# 2016-03-11    0.033018
# 2016-03-12    0.037320
# 2016-03-13    0.015522
# 2016-03-14    0.036300
# 2016-03-15    0.034016
# 2016-03-16    0.029359
# 2016-03-17    0.031155
# 2016-03-18    0.012883
# 2016-03-19    0.034747
# 2016-03-20    0.038073
# 2016-03-21    0.037741
# 2016-03-22    0.033018
# 2016-03-23    0.032397
# 2016-03-24    0.028982
# 2016-03-25    0.031089
# 2016-03-26    0.032641
# 2016-03-27    0.031177
# 2016-03-28    0.034836
# 2016-03-29    0.033262
# 2016-03-30    0.033328
# 2016-03-31    0.031665
# 2016-04-01    0.033905
# 2016-04-02    0.035767
# 2016-04-03    0.038827
# 2016-04-04    0.036610
# 2016-04-05    0.013172
# 2016-04-06    0.003171
# 2016-04-07    0.001353
# Name: date_crawled, dtype: float64

# %% [markdown]
# We are looking at 45097 entry points for these dates.
#
# The data crawled was for approximately 30 days. It can be seen that in the beginning of April 2016 the data crawled has drastically went down compared with March 2016

# %%
autos["ad_created"].str[:10].shape
# Out:
# (45097,)

# %%
autos["ad_created"].str[:10].value_counts(normalize= True, dropna= False).sort_index(ascending= True)
# Out:
# 2015-06-11    0.000022
# 2015-08-10    0.000022
# 2015-09-09    0.000022
# 2015-11-10    0.000022
# 2015-12-05    0.000022
# 2015-12-30    0.000022
# 2016-01-03    0.000022
# 2016-01-07    0.000022
# 2016-01-10    0.000044
# 2016-01-13    0.000022
# 2016-01-14    0.000022
# 2016-01-16    0.000022
# 2016-01-22    0.000022
# 2016-01-27    0.000067
# 2016-01-29    0.000022
# 2016-02-01    0.000022
# 2016-02-02    0.000044
# 2016-02-05    0.000044
# 2016-02-07    0.000022
# 2016-02-08    0.000022
# 2016-02-09    0.000022
# 2016-02-11    0.000022
# 2016-02-12    0.000044
# 2016-02-14    0.000044
# 2016-02-16    0.000022
# 2016-02-17    0.000022
# 2016-02-18    0.000044
# 2016-02-19    0.000067
# 2016-02-20    0.000044
# 2016-02-21    0.000044
#                 ...
# 2016-03-09    0.032996
# 2016-03-10    0.032441
# 2016-03-11    0.033328
# 2016-03-12    0.037098
# 2016-03-13    0.016963
# 2016-03-14    0.034880
# 2016-03-15    0.033794
# 2016-03-16    0.029847
# 2016-03-17    0.030822
# ...

# %% [markdown]
# We are following 45097 listings created between June 2015 up to April 2016.
#
# From June 2015 and up until 21st of February 2016, the frequency for creating a selling post was very low: between 0,0022% - 0,0067%. Some strange distribution

# %%
autos["last_seen"].str[:10].shape
# Out:
# (45097,)

# %%
autos["last_seen"].str[:10].value_counts(normalize= True, dropna= False).sort_index(ascending= True)
# Out:
# 2016-03-05    0.001087
# 2016-03-06    0.004169
# 2016-03-07    0.005211
# 2016-03-08    0.007007
# 2016-03-09    0.009468
# 2016-03-10    0.010289
# 2016-03-11    0.012041
# 2016-03-12    0.023904
# 2016-03-13    0.008870
# 2016-03-14    0.012285
# 2016-03-15    0.015677
# 2016-03-16    0.016165
# 2016-03-17    0.027674
# 2016-03-18    0.007406
# 2016-03-19    0.015411
# 2016-03-20    0.020423
# 2016-03-21    0.020667
# 2016-03-22    0.021243
# 2016-03-23    0.018405
# 2016-03-24    0.019536
# 2016-03-25    0.018582
# 2016-03-26    0.016476
# 2016-03-27    0.015456
# 2016-03-28    0.020534
# 2016-03-29    0.021354
# 2016-03-30    0.024148
# 2016-03-31    0.023438
# 2016-04-01    0.022862
# 2016-04-02    0.024880
# 2016-04-03    0.024946
# 2016-04-04    0.024303
# 2016-04-05    0.126616
# 2016-04-06    0.225314
# 2016-04-07    0.134155
# Name: last_seen, dtype: float64

# %% [markdown]
# It seems that more users have been last seen in April. It might be that right then they have sold the car they listed

# %%
autos["registration_year"].describe()
# Out:
# count    45097.000000
# mean      2005.064173
# std         89.652017
# min       1000.000000
# 25%       2000.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# For the `registration_year` we find two very peculiar dates:
# - the minum value, also the earliest registration date, is the year 1000 (before cars were invented)
# - the maximum value, also the most recent registration date, is the year 9999 which is in the future
#
# Because a car can't be first registered after the listing was seen, any vehicle with a registration year above 2016 is definitely inaccurate, since the data is from 2016. Determining the earliest valid year is more difficult. Realistically, it could be somewhere in the first few decades of the 1900s.
#
# I will explore the number of listings that are outside 1900 - 2016 interval and see if I can remove the entire row or if I need to write a custom code this.

# %%
autos["registration_year"].value_counts().sort_index()
# Out:
# 1000       1
# 1001       1
# 1910       2
# 1927       1
# 1929       1
# 1931       1
# 1934       2
# 1937       4
# 1938       1
# 1939       1
# 1941       2
# 1943       1
# 1948       1
# 1950       1
# 1951       2
# 1952       1
# 1953       1
# 1954       2
# 1955       2
# 1956       4
# 1957       2
# 1958       4
# 1959       6
# 1960      19
# 1961       6
# 1962       4
# 1963       8
# 1964      11
# 1965      17
# 1966      21
#         ...
# 2000    2715
# 2001    2520
# 2002    2419
# 2003    2657
# 2004    2683
# 2005    2864
# 2006    2666
# 2007    2270
# 2008    2206
# 2009    2078
# 2010    1586
# 2011    1617
# 2012    1307
# 2013     797
# 2014     652
# 2015     364
# 2016     950
# 2017    1296
# 2018     462
# 2019       1
# 2800       1
# 4100       1
# 4500       1
# 4800       1
# 5000       2
# 5911       1
# 6200       1
# 8888       1
# 9000       1
# 9999       3
# Name: registration_year, Length: 93, dtype: int64

# %% [markdown]
# After exploring the series `autos['registration_year']`, I decided to select the interval 1950 - 2016. I will make use of the `df[df['col_name'].between(x, y)]` method and to update the autos dataframe

# %%
autos= autos[autos["registration_year"].between(1950, 2016)]

# %%
autos["registration_year"].value_counts(normalize= True).sort_index()
# Out:
# 1950    0.000023
# 1951    0.000046
# 1952    0.000023
# 1953    0.000023
# 1954    0.000046
# 1955    0.000046
# 1956    0.000092
# 1957    0.000046
# 1958    0.000092
# 1959    0.000139
# 1960    0.000439
# 1961    0.000139
# 1962    0.000092
# 1963    0.000185
# 1964    0.000254
# 1965    0.000393
# 1966    0.000485
# 1967    0.000600
# 1968    0.000600
# 1969    0.000439
# 1970    0.000785
# 1971    0.000577
# 1972    0.000716
# 1973    0.000531
# 1974    0.000554
# 1975    0.000416
# 1976    0.000485
# 1977    0.000508
# 1978    0.000970
# 1979    0.000785
#           ...
# 1987    0.001570
# 1988    0.002979
# 1989    0.003579
# 1990    0.006327
# 1991    0.006766
# 1992    0.007043
# 1993    0.007851
# 1994    0.011546
# 1995    0.019859
# 1996    0.024754
# 1997    0.034914
# 1998    0.046783
# 1999    0.059391
# 2000    0.062693
# 2001    0.058191
# 2002    0.055858
# 2003    0.061354
# 2004    0.061954
# 2005    0.066134
# 2006    0.061562
# 2007    0.052418
# ...

# %% [markdown]
# Majority of the cars were registered starting with the 1990's, with a very big occurence during the interval 1998-2009

# %%
autos["brand"].describe()
# Out:
# count          43306
# unique            40
# top       volkswagen
# freq            9179
# Name: brand, dtype: object

# %% [markdown]
# There is an occurence where there is a brand called `sonstige_autos` but from my research this represents other type of brands that may not be relevant or the owner did not tag his car with a brand name.
#
# Since this is not relevant to my analysis in finding data about specific brands, I will drop off the rows with these tags.

# %%
find_row= autos[autos["brand"] == "sonstige_autos"].index
autos= autos.drop(find_row)

# %%
autos["brand"].value_counts(normalize= True) * 100
# Out:
# volkswagen       21.399762
# bmw              11.614949
# mercedes_benz    10.323363
# opel             10.129858
# audi              9.141352
# ford              6.574499
# renault           4.431959
# peugeot           2.965519
# fiat              2.375679
# seat              1.806822
# skoda             1.732217
# smart             1.527056
# mazda             1.515399
# nissan            1.515399
# citroen           1.429138
# toyota            1.354533
# hyundai           1.025808
# mini              0.946541
# volvo             0.946541
# honda             0.788007
# mitsubishi        0.781013
# kia               0.741380
# alfa_romeo        0.669107
# porsche           0.648124
# chevrolet         0.608491
# suzuki            0.596834
# chrysler          0.363696
# dacia             0.286760
# jeep              0.247127
# land_rover        0.228476
# daihatsu          0.219150
# subaru            0.200499
# saab              0.167860
# jaguar            0.163197
# ...

# %%
auto_brands= autos["brand"].value_counts().head(10).index
auto_brands
# Out:
# Index(['volkswagen', 'bmw', 'mercedes_benz', 'opel', 'audi', 'ford', 'renault',
#        'peugeot', 'fiat', 'seat'],
#       dtype='object')

# %%
brand_mean_prices= {}

for b in auto_brands:
    selected_rows= autos[autos["brand"] == b]
    sorted_rows= selected_rows.sort_values("price", ascending= False)
    mean= sorted_rows["price"].mean().round()
    brand_mean_prices[b] = int(mean)

brand_mean_prices
# Out:
# {'audi': 9614,
#  'bmw': 8582,
#  'fiat': 3256,
#  'ford': 4278,
#  'mercedes_benz': 8764,
#  'opel': 3395,
#  'peugeot': 3361,
#  'renault': 2820,
#  'seat': 4811,
#  'volkswagen': 5780}

# %% [markdown]
# I can see that Mini, Audi, Mercedes Benz and BMW are among the most expensive cars, while at the other end there is Renault, Fiat, Peugeot and Opel.
#
# The most popular car brand, Volkswagen, is in between as price making it an affordable car for medium-income people.

# %%
brand_mean_mileage= {}

for b in auto_brands:
    selected_rows= autos[autos["brand"] == b]
    sorted_rows= selected_rows.sort_values("odometer_km", ascending= False)
    mean= sorted_rows["odometer_km"].mean().round()
    brand_mean_mileage[b]= int(mean)
    
brand_mean_mileage
# Out:
# {'audi': 128910,
#  'bmw': 132891,
#  'fiat': 114416,
#  'ford': 123619,
#  'mercedes_benz': 131064,
#  'opel': 128036,
#  'peugeot': 126073,
#  'renault': 126415,
#  'seat': 120058,
#  'volkswagen': 128238}

# %%
bmp_series= pd.Series(brand_mean_prices)
bmp_series
# Out:
# audi             9614
# bmw              8582
# fiat             3256
# ford             4278
# mercedes_benz    8764
# opel             3395
# peugeot          3361
# renault          2820
# seat             4811
# volkswagen       5780
# dtype: int64

# %%
bmp_df= pd.DataFrame(bmp_series, columns= ["mean_price"])
bmp_df
# Out:
#                mean_price
# audi                 9614
# bmw                  8582
# fiat                 3256
# ford                 4278
# mercedes_benz        8764
# opel                 3395
# peugeot              3361
# renault              2820
# seat                 4811
# volkswagen           5780

# %%
bmm_series= pd.Series(brand_mean_mileage)
bmp_df["mean_mileage"]= bmm_series

# %%
bmp_df
# Out:
#                mean_price  mean_mileage
# audi                 9614        128910
# bmw                  8582        132891
# fiat                 3256        114416
# ford                 4278        123619
# mercedes_benz        8764        131064
# opel                 3395        128036
# peugeot              3361        126073
# renault              2820        126415
# seat                 4811        120058
# volkswagen           5780        128238
